# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df=pd.read_csv("/content/Testing.csv")
df.shape
# Out:
# (85, 135)

# %%
import pandas as pd

data_true = pd.read_csv("/content/Testing.csv")
dm = data_true.tail(10)
dm1= data_true.head(9)
dmerge=pd.concat([dm,dm1],axis=0)
dmerge.to_csv("manual_testing.csv")
print(dmerge.groupby(['itching'])['skin_rash'].count())
# Out:
# itching
# 0    15
# 1     4
# Name: skin_rash, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
runs=np.array([100,50,91,78,89,25,34,19,9,10])
w=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,w,color='orange')
plt.title("INDvsAUS_score")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
runs=np.array([1,2,3,4,5,6,7,8])
w=np.array([1,2,3,4,5,6,7,8])
plt.scatter(runs,w,color='orange')
plt.title("INDvsAUS_score")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
tigar=np.linspace(-2*np.pi,2*np.pi,50)
print(tigar)
plt.plot(tigar,np.sin(tigar),color='blue')
plt.title("sin(x)")
plt.show()
# Out:
# [-6.28318531 -6.02672876 -5.77027222 -5.51381568 -5.25735913 -5.00090259
#  -4.74444605 -4.48798951 -4.23153296 -3.97507642 -3.71861988 -3.46216333
#  -3.20570679 -2.94925025 -2.6927937  -2.43633716 -2.17988062 -1.92342407
#  -1.66696753 -1.41051099 -1.15405444 -0.8975979  -0.64114136 -0.38468481
#  -0.12822827  0.12822827  0.38468481  0.64114136  0.8975979   1.15405444
#   1.41051099  1.66696753  1.92342407  2.17988062  2.43633716  2.6927937
#   2.94925025  3.20570679  3.46216333  3.71861988  3.97507642  4.23153296
#   4.48798951  4.74444605  5.00090259  5.25735913  5.51381568  5.77027222
#   6.02672876  6.28318531]

# %%
import numpy as np
import matplotlib.pyplot as plt
#creating x
overs=np.arange(5,50,5)
overs_a=np.arange(5,30,5)
#creating y
runs_i=np.array([25,51,84,131,160,189,220,250,267])
runs_a=np.array([15,41,94,110,151])
wickest=np.array([12,32,96])
plt.subplot(2,1,2)
plt.plot(overs,runs_i,color="blue",label='India')
plt.legend(loc="best")

plt.subplot(2,1,1)
plt.plot(overs_a,runs_a,color='yellow',label='Aus')
plt.legend(loc="best")

#displaying graph


plt.show()

# %%
import matplotlib.pyplot as plt

a=[230,560,780,127,128]
b=[200,160,270,127,400]
years=[1,2,3,4]
profit_a=[(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b=[(b[i]-b[i-1]) for i in range(1,len(b))]

plt.subplot(2,1,2)

plt.plot(years,profit_a,color="red",linewidth='3',label='CompanyA',marker='>',ms='15',mec='k')
plt.legend(loc="best")
plt.subplot(2,1,1)

plt.plot(years,profit_b,color="black",linestyle='dotted',label='CompanyB',marker='H')
plt.legend(loc="best")

# %%
import matplotlib.pyplot as plt

runs_a=[101,103,120,221,130]
runs_b=[99,91,100,92,95]
matches=[1,2,3,4,5]

wickets_a=[(a[i]-a[i-1]) for i in range(1,len(runs_a))]
wickest_b=[(a[i]-a[i-1]) for i in range(1,len(runs_b))]
plt.plot(matches,runs_a,color="RED",linewidth=2,label="RCB",marker=">")
plt.legend(loc="best")
plt.plot(matches,runs_b,color="yellow",linewidth=2,label="CSK",marker=".")
plt.legend(loc="best")

# %%
import numpy as np
a=np.array([25,60,5,10])
colors=["RED","GREEN","YELLOW","BLUE"]
label=(["AIML","PYTHON","PANDAS","NUMPY"])

explo=[0.2,0,0,0]
plt.pie(a,labels=label,explode=explo,startangle=180,colors=colors,textprops={'fontsize':14})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
a=np.array([50,15,35,1])
label=(["RCB","CSK","GT","MI"])
list=["RED","YELLOW","DARKBLUE","BLUE"]

plt.pie(a,labels=label,colors=list,textprops={'fontsize':16})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
